# %%
from homeharvest import scrape_property
from datetime import datetime
import pandas as pd

current_timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

listings = scrape_property(
    location="Virginia",
    listing_type="for_sale",
    past_days=30
)

print(listings.shape)
print(listings.head())

listings.to_csv(f"fairfax_homeharvest_{current_timestamp}.csv", index=False)
# Out:
# (9800, 66)
#                                         property_url property_id  listing_id  \
# 0  https://www.realtor.com/realestateandhomes-det...  9381932290  2994319108
# 1  https://www.realtor.com/realestateandhomes-det...  6439748965  2994003318
# 2  https://www.realtor.com/realestateandhomes-det...  9061767591  2993084850
# 3  https://www.realtor.com/realestateandhomes-det...  6017586337  2993592854
# 4  https://www.realtor.com/realestateandhomes-det...  6147511066  2993999382
#
#                                            permalink   mls    mls_id  \
# 0  1203-Wolf-Trap-Rd_South-Boston_VA_24592_M93819...  STNY  11695439
# 1  90-Old-Preston-Rd_Martinsville_VA_24112_M64397...  MAVA    150043
# 2  8153-E-Patrick-Henry-Rd_Ashland_VA_23005_M9061...  CEVA   2607423
# 3  145-Via-Mountain-Ln_Patrick-Springs_VA_24133_M...  ROVA    926460
# 4  5630-Spring-Meadow-Dr_Roanoke_VA_24018_M61475-...  ROVA    926569
#
#      status mls_status                                               text  \
# 0  FOR_SALE     Active  List price is starting bid only. Home will be ...
# 1  FOR_SALE     Active  HOME CAN NOT BE ENTERED. Sold strictly as is. ...
# 2  FOR_SALE     Active  Charming 1 Level Rambler Situated on a Generou...
# 3  FOR_SALE     Active  Auction Property: List price may not reflect f...
# 4  FOR_SALE     Active  Property is owned by the US Dept of HUD, home ...
#
#            style  ... builder_id builder_name office_id office_mls_set  \
# 0  SINGLE_FAMILY  ...       <NA>         <NA>      <NA>    O-STNY-6692
# 1  SINGLE_FAMILY  ...       <NA>         <NA>    789922     O-MAVA-173
# 2  SINGLE_FAMILY  ...       <NA>         <NA>      <NA>  O-CEVA-ANRR01
# 3  SINGLE_FAMILY  ...       <NA>         <NA>   3016515  O-ROVA-BLUE01
# 4  SINGLE_FAMILY  ...       <NA>         <NA>   2938757  O-ROVA-PRES01
#
#                                          office_name  \
# 0                   Nicholls Auction Marketing Group
# 1                                  Adams Realty,Inc.
# 2                                         ANR Realty
# 3  UNITED COUNTRY / BLUE RIDGE LAND & AUCTION CO ...
# 4                     Prime Real Estate Services Inc
#
#                          office_email  \
# 0                                <NA>
# 1  patti@adamsrealtyofhenrycounty.com
# 2              richmond@anrrealty.com
# 3                    brlanda@swva.net
# 4                 ayers1809@gmail.com
#
#                                        office_phones nearby_schools  \
# 0  [{'number': '(540) 898-0971', 'type': 'Office'...           <NA>
# 1  [{'number': '2766475277', 'type': 'Office', 'p...           <NA>
# 2  [{'number': '7576830118', 'type': None, 'prima...           <NA>
# 3  [{'number': '5407452005', 'type': 'Mobile', 'p...           <NA>
# 4  [{'number': '5403006311', 'type': 'Office', 'p...           <NA>
#
#                                        primary_photo  \
# 0  https://ap.rdcpix.com/8a2ee647fe2b7867eae19b8e...
# 1  https://ap.rdcpix.com/687ec51649b83caf6272fae3...
# 2  https://ap.rdcpix.com/009914738fbee4b9e45410c3...
# 3  https://ap.rdcpix.com/b3a4eb5ef3e79d4c8d8fbe03...
# 4  https://ap.rdcpix.com/2fa64f80f455af95ded89775...
#
#                                           alt_photos
# 0  https://ap.rdcpix.com/8a2ee647fe2b7867eae19b8e...
# 1  https://ap.rdcpix.com/687ec51649b83caf6272fae3...
# 2  https://ap.rdcpix.com/009914738fbee4b9e45410c3...
# 3  https://ap.rdcpix.com/b3a4eb5ef3e79d4c8d8fbe03...
# 4  https://ap.rdcpix.com/2fa64f80f455af95ded89775...
#
# [5 rows x 66 columns]

# %%
listings.to_csv("virginia_housing_raw.csv", index=False)
